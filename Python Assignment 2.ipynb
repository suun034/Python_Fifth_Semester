# %% [markdown]
# Q1. Perform a Fast Fourier Transform (FFT) on a sine wave signal and visualize both the original signal and its frequency spectrum.
#
# Source Code:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
sampling_rate = 1000  # Samples per second
frequency = 5         # Frequency of the sine wave in Hz
amplitude = 1         # Amplitude of the sine wave
duration = 1          # Duration of the signal in seconds

# Time array
t = np.linspace(0, duration, sampling_rate * duration, endpoint=False)

# Generate sine wave
sine_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# Perform FFT
magnitude_fft = np.abs(np.fft.fft(sine_wave))
frequency_fft = np.fft.fftfreq(len(magnitude_fft), 1 / sampling_rate)

# Plot the original sine wave and its frequency spectrum
plt.figure(figsize=(12, 6))

# Plot the original sine wave
plt.subplot(2, 1, 1)
plt.plot(t, sine_wave, color='pink')
plt.title('Original Sine Wave')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()

# Plot the frequency spectrum (only positive frequencies)
plt.subplot(2, 1, 2)
plt.plot(frequency_fft[:len(frequency_fft) // 2], magnitude_fft[:len(magnitude_fft) // 2], color='green')
plt.title('Frequency Spectrum')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()

# Display plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Q2. Use the scipy library to numerically integrate the function f(x) = x^2 over
# the range [0,5].
#
# Source Code:

# %%
from scipy import integrate

def f(x):
    return x**2

result, error = integrate.quad(f, 0, 5)
print("The integration value is: ", result)
print("The error value is: ", error)
# Out:
# The integration value is:  41.66666666666667
# The error value is:  4.625929269271486e-13

# %% [markdown]
# Q3. Solve a simple optimization problem where you need to minimize the
# function f(x) = (x-3)^2+2 using scipy.optimize.
#
# Source Code:

# %%
import numpy as np
from scipy.optimize import minimize

def f(x):
    return (x - 3)**2 + 2

result = minimize(f, 0)
print("The optimized value is: ", result.fun)
print("The value of x which optimizes the function is: ", result.x)
# Out:
# The optimized value is:  2.000000000000001
# The value of x which optimizes the function is:  [3.00000003]

# %% [markdown]
# Q4. Solve a system of linear equations using numpy. Given the system:
#     2x+3y = 5
#     4x+y = 6
#     Solve for x & y.
#
# Source Code:

# %%
import numpy as np

m = np.array([[2, 3], [4, 1]])
n = np.array([5, 6])

result = np.linalg.solve(m, n)
print("The solution of the system of equations: ", result)
# Out:
# The solution of the system of equations:  [1.3 0.8]
